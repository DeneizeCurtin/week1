# %% [markdown]
# <a href="https://colab.research.google.com/github/DeneizeCurtin/week1/blob/main/Deneize_workbook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello World!")
print("I am learning Python.")
# Out:
# Hello World!
# I am learning Python.

# %%
print ("Python is versatile!")
print ("I am learning python!")
# Out:
# Python is versatile!
# I am learning python!

# %%
print("Hello")
print("Python!")
# Out:
# Hello
# Python!
