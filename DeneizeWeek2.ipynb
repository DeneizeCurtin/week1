# %% [markdown]
# <a href="https://colab.research.google.com/github/DeneizeCurtin/week1/blob/main/DeneizeWeek2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sample survey programme

# Ask the user for their preferences
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")

# Construct and display a summary message
print("\nHello, " + name + "!")
print("Your favourite colour is " + favourite_colour + ", you love " + favourite_food +
      ", and your favourite movie is " + favourite_movie + ".")
# Out:
# What's your name? Deneize
# What's your favourite colour? Purple
# What's your favourite food? Pizza
# What's your favourite movie? The perks of being a wallflower
#
# Hello, Deneize!
# Your favourite colour is Purple, you love Pizza, and your favourite movie is The perks of being a wallflower.

# %% [markdown]
# Challenge 1 - Multi Line greeting

# %%
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")

print("Hi" ,name,) \n print("Your favorite color is",favourite_colour)
# Out:
#   File "/tmp/ipykernel_1132/1255652893.py", line 4
#     print("Hi" ,name,) \n print("Your favorite color is",favourite_colour)
#                         ^
# SyntaxError: unexpected character after line continuation character

# %%
name = input("What's your name? ")
favourite_colour = input("What's your favourite colour? ")
favourite_food = input("What's your favourite food? ")
favourite_movie = input("What's your favourite movie? ")
hobby = input("What's your favourite hobby? ")

# Construct and display a summary message
print("*","Name" , "=", name)
print("*","Favourite_colour ", "=", favourite_colour)
print("*","Favourite_food ", "=", favourite_food)
print("*","Favourite_movie ", "=", favourite_movie)
print("*","Hobby ", "=", hobby)
# Out:
# What's your name? Deneize
# What's your favourite colour? Purple
# What's your favourite food? Pizza
# What's your favourite movie? The perks of being a wallflower
# What's your favourite hobby? Reading
# * Name = Deneize
# * Favourite_colour  = Purple
# * Favourite_food  = Pizza
# * Favourite_movie  = The perks of being a wallflower
# * Hobby  = Reading

# %% [markdown]
# Challenge 2

# %%
print("Hi", name,"!","Your favorite color is", favourite_colour, ", and your favorite food is",favourite_food,"!", "Yum that's mine too. We also share a favorite hobby which is ",hobby,". How exciting :) I will add your favorite movie", favourite_movie,"to my list." )
# Out:
# Hi Deneize ! Your favorite color is Purple , and your favorite food is Pizza ! Yum that's mine too. We also share a favorite hobby which is  Reading . How exciting :) I will add your favorite movie The perks of being a wallflower to my list.
